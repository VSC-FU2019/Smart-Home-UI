# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
import os
from keras.models import load_model
from python_speech_features import mfcc, logfbank, delta
from pydub import AudioSegment
import pyaudio
import IPython
from keras.preprocessing.sequence import pad_sequences
import scipy
import scipy.signal
import sys
import wave
from queue import Queue
from threading import Thread
# Out:
# Using TensorFlow backend.

# %%
model = load_model("./train.h5")
# Out:
# WARNING:tensorflow:From c:\users\giangtm\appdata\local\conda\conda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\giangtm\appdata\local\conda\conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From c:\users\giangtm\appdata\local\conda\conda\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 200, 128)          3456
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200, 128)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 200, 32)           20608
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200, 32)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 200, 64)           24832
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200, 64)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               98816
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                2064
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# =================================================================
# Total params: 149,776
# Trainable params: 149,776
# Non-trainable params: 0
# _________________________________________________________________

# %%
NUMB_CEP = 26
NUMB_FILT = 26
NFFT = 512
DELTA = 2
MFCC_LEN = 200

# %%
def get_feature(y, fs):
    y = y / np.max(abs((y)))
    mfcc_feat = mfcc(y, fs, numcep=NUMB_CEP)
    mfcc_feat = delta(mfcc_feat, DELTA)
    
    return mfcc_feat

def preprocess_data(y, fs):
    b = scipy.signal.firwin(255, [300, 3400], pass_zero=False, fs=fs)
    y_filter = scipy.signal.filtfilt(b, 1, y)
    return y_filter
    
def get_data(y, fs):
    input_data = []
    #y_filt = preprocess_data(y, fs)
    mfcc_feat = get_feature(y, fs)
    
    input_data.append(mfcc_feat)

    input_data[0] = pad_sequences(input_data[0].T, MFCC_LEN, dtype=float, padding='post', truncating='post').T
    input_data = np.array([input_data[0]])
    return input_data

def print_command(probabilities):
    arg_max = np.argmax(probabilities[0])
    if probabilities[0, arg_max] >= 0.75:
        if arg_max == 0:
            print("Background")
        if arg_max == 1:
            print("Bat den")
        elif arg_max == 2:
            print("Tat den")
        elif arg_max == 3:
            print("Bat dieu hoa")
        elif arg_max == 4:
            print("Tat dieu hoa")
        elif arg_max == 5:
            print("Bat quat")
        elif arg_max == 6:
            print("Tat quat")
        elif arg_max == 7:
            print("Bat tivi")
        elif arg_max == 8:
            print("Tat tivi")
        elif arg_max == 9:
            print("Mo cua")
        elif arg_max == 10:
            print("Dong cua")
        elif arg_max == 11:
            print("Khoa cua")
        elif arg_max == 12:
            print("Mo cong")
        elif arg_max == 13:
            print("Dong cong")
        elif arg_max == 14:
            print("Khoa cong")
        elif arg_max == 15:
            print("Doremon")
    else:
        sys.stdout.write("-")

# %%
### ghi âm và ghi ra file 
FORMAT = pyaudio.paInt16 
CHANNELS = 1
RATE = 8000
CHUNK = 4000
WAVE_OUTPUT_FILENAME = "test.wav"

audio = pyaudio.PyAudio()
stream = audio.open(format=FORMAT, channels=CHANNELS,
                rate=RATE, input=True,
                frames_per_buffer=CHUNK)

seconds_rec_numb = 2    ## recording in 2 second
frames = []

try:
    for i in range(0, int(seconds_rec_numb * RATE / CHUNK)):
        sys.stdout.write("-")
        data = stream.read(CHUNK)
        frames.append(data)
except (KeyboardInterrupt, SystemExit):
    stream.stop_stream()
    stream.close()
    
stream.stop_stream()
stream.close()
audio.terminate()
 
waveFile = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
waveFile.setnchannels(CHANNELS)
waveFile.setsampwidth(audio.get_sample_size(FORMAT))
waveFile.setframerate(RATE)
waveFile.writeframes(b''.join(frames))
waveFile.close()
# Out:
# ----

# %%
## nghe lại audio vừa ghi âm
IPython.display.Audio("test.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
## predict file ghi âm 
file_name = "./test.wav"
fs, y = wavfile.read(file_name)

x = get_data(y, fs)
prob = model.predict(x, verbose=1)
print(prob)
print_command(prob)
# Out:
# 1/1 [==============================] - 1s 872ms/step
# [[0.40333965 0.0058311  0.01046597 0.06893883 0.01479391 0.01390462
#   0.00329601 0.01543166 0.01847607 0.00259428 0.05679455 0.01335789
#   0.01149432 0.20914482 0.014479   0.13765731]]
# -

# %%
### record and predict
FORMAT = pyaudio.paInt16 
CHANNELS = 1
RATE = 8000
CHUNK = 1000
#WAVE_OUTPUT_FILENAME = "record.wav"

audio = pyaudio.PyAudio()
stream = audio.open(format=FORMAT, channels=CHANNELS,
                rate=RATE, input=True,
                frames_per_buffer=CHUNK)

seconds_rec_numb = 2    ## recording in 2 second
y = np.zeros((RATE * seconds_rec_numb, ), dtype='int16')

try:
    for i in range(0, int(seconds_rec_numb * RATE / CHUNK)):
        sys.stdout.write("-")
        data = stream.read(CHUNK)
        y[CHUNK * i : CHUNK * (i+1)] = np.frombuffer(data, dtype='int16')
except (KeyboardInterrupt, SystemExit):
    stream.stop_stream()
    stream.close()
    
stream.stop_stream()
stream.close()
audio.terminate()

x = get_data(y, RATE)
prob = model.predict(x, verbose=1)
print(prob)
print_command(prob)
#waveFile = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
#waveFile.setnchannels(CHANNELS)
#waveFile.setsampwidth(audio.get_sample_size(FORMAT))
#waveFile.setframerate(RATE)
#waveFile.writeframes(b''.join(frames))
#waveFile.close()
# Out:
# 1/1 [==============================] - 0s 382ms/step
# [[7.0185654e-02 1.2297672e-02 3.9782579e-04 1.4417687e-01 3.8070183e-03
#   3.9218567e-02 5.4381136e-03 5.1692829e-02 6.7309779e-03 7.4570730e-02
#   3.0323103e-02 7.6123187e-03 4.7142193e-01 6.3199379e-02 1.0789462e-02
#   8.1375511e-03]]
# -

# %%
### record and predict real time 
FORMAT = pyaudio.paInt16 
CHANNELS = 1
RATE = 8000
CHUNK = 4000
#WAVE_OUTPUT_FILENAME = "record.wav"

q = Queue()
seconds_rec_numb = 2    ## recording in 2 second
feed_samples = int(RATE * seconds_rec_numb)

data = np.zeros(feed_samples, dtype='int16')

def audio_callback(in_data, frame_count, time_info, status):
    global q, data
    data0 = np.frombuffer(in_data, dtype='int16')
    
    data = np.append(data, data0)
    if len(data) > feed_samples:
        data = data[-feed_samples:]
        
        q.put(data)
    return (in_data, pyaudio.paContinue)

audio = pyaudio.PyAudio()
stream = audio.open(format=FORMAT, channels=CHANNELS,
                rate=RATE, input=True,
                frames_per_buffer=CHUNK, stream_callback=audio_callback)
stream.start_stream()
try:
    
    while True:
        y = q.get()
        x = get_data(y, RATE)
        prob = model.predict(x)
            
        print_command(prob)
except (KeyboardInterrupt, SystemExit):
    stream.stop_stream()
    stream.close()
    
stream.stop_stream()
stream.close()
audio.terminate()
# Out:
# Background
# Bat dieu hoa
# Background
# Background
# Background
# ---------Background
# -Bat tivi
# -Doremon
# Doremon
# Doremon
# ---Bat den
# -Tat tivi
# Tat tivi
# -Background
# --Doremon
# ----Bat dieu hoa
# ---Doremon
# -Bat tivi
# Doremon
# Doremon
# --Background
# -Doremon
# Bat tivi
# Bat tivi
# Bat tivi
# Doremon
# -Background
# -----Background
# Background
# --Bat tivi
# --Doremon
# Background
# Background
# Background
# Doremon
# Doremon
# Background
# -Doremon
# Bat tivi
# --Doremon
# --Bat tivi
# Background
# -Tat tivi
# Tat tivi
# Tat tivi
# --Tat tivi
# --Background
# ---Bat tivi
# Bat tivi
# Tat tivi
# ---Bat dieu hoa
# ---Background
# -Bat tivi
# Bat dieu hoa
# -Doremon
# Bat tivi
# Bat dieu hoa
# Bat dieu hoa
# Bat dieu hoa
# -Background
# Doremon
# Doremon
# -Background
# -Doremon
# Background
# Background
# -Tat tivi
# -----Bat tivi
# --Background
# Background
# Bat tivi
# Background
# -Tat tivi
# --Background
# Background
# Background
# Background
# Background
# -Khoa cong
# Background
# ----Tat tivi
# Tat tivi
# Tat tivi
# Tat tivi
# Bat tivi
# Bat tivi
# Khoa cua
# -Bat tivi
# Background
# Bat tivi
# Bat tivi
# Bat tivi
# Background
# Tat tivi
# Tat tivi
# Tat tivi
# Background
# Bat tivi
# Bat tivi
# --Background
# Doremon
# ---Background
# Background
# Tat tivi
# Tat tivi
# Tat tivi
# Tat tivi
# Background
# Background
# Bat tivi
# Background
# Tat tivi
# -Background
# ---Tat dieu hoa
# Khoa cong
# ---Background
# Background
# Background
# --Bat tivi
# -Background
# -Background
# Background
# Background
# Background
# Tat den
# Tat den
# -----Bat tivi
# Tat tivi
# --Background
# Background
# Background
# -Doremon
# -Doremon
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# ---Bat tivi
# --Background
# Background
# Background
# --Tat tivi
# Background
# Tat tivi
# Doremon
# -Background
# Background
# --Background
# Background
# Background
# Background
# Background
# ----Bat quat
# -Background
# -Background
# -Mo cong
# Background
# -Bat tivi
# Bat tivi
# Background
# -Bat dieu hoa
# ----Background
# --Bat tivi
# -Background
# -Background
# -Mo cong
# Dong cua
# -Background
# ---Background
# Background
# --Background
# Background
# -Tat dieu hoa
# Tat dieu hoa
# Tat dieu hoa
# -Background
# -Doremon
# Doremon
# Doremon
# -Khoa cong
# Khoa cong
# Khoa cong
# -Doremon
# Doremon
# Doremon
# Doremon
# ----Doremon
# Background
# -Doremon
# Doremon
# ------Background
# -Background
# Background
# --Khoa cong
# -Khoa cong
# Doremon
# --Tat tivi
# Doremon
# Doremon
# Doremon
# Background
# Background
# --Background
# Background
# Khoa cong
# Background
# Background
# Background
# Background
# Doremon
# Doremon
# Background
# Mo cua
# -Background
# Background
# Background
# ---Bat tivi
# -Background
# Background
# -Bat dieu hoa
# Bat tivi
# ------Doremon
# -Bat tivi
# Background
# ---Khoa cong
# Tat tivi
# Bat dieu hoa
# Doremon
# ----Doremon
# ------Background
# Background
# -Bat tivi
# --Doremon
# Doremon
# Background
# Bat dieu hoa
# --Background
# -Doremon
# Doremon
# ---Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Doremon
# Doremon
# Bat tivi
# Bat dieu hoa
# Bat dieu hoa
# Doremon
# -----Doremon
# Doremon
# -----Khoa cua
# -Tat tivi
# Tat dieu hoa
# Tat dieu hoa
# ----Background
# Background
# ------Mo cua
# Doremon
# Doremon
# -Background
# Background
# Background
# Background
# Background
# Background
# -Background
# Background
# Background
# Background
# Background
# -Tat tivi
# Background
# Background
# ----Bat dieu hoa
# Doremon
# Doremon
# Bat tivi
# Bat dieu hoa
# -Khoa cong
# Background
# Tat tivi
# Tat tivi
# ----Tat dieu hoa
# --Bat dieu hoa
# --Background
# Background
# ---Background
# Bat tivi
# ---Khoa cong
# --Background
# Tat tivi
# Background
# Background
# Background
# Background
# Background
# Bat tivi
# Background
# Background
# Bat tivi
# -Khoa cua
# Khoa cua
# --Bat tivi
# Background
# Background
# Background
# Background
# Background
# -Bat dieu hoa
# Bat dieu hoa
# -Background
# Background
# Background
# -Background
# --Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Doremon
# -Bat den
# -Background
# -Dong cua
# Background
# Dong cong
# -Background
# Background
# -Doremon
# Doremon
# Doremon
# Doremon
# Doremon
# -Doremon
# --Background
# Background
# Background
# Background
# Background
# Background
# -Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# --Doremon
# Doremon
# --Background
# --Doremon
# Background
# Background
# -Background
# ---Bat tivi
# Background
# -Bat tivi
# -Background
# -Background
# Background
# Background
# ----Background
# Background
# Background
# ----Bat quat
# Doremon
# Doremon
# ---Background
# Background
# Doremon
# Background
# Background
# -Doremon
# Doremon
# Doremon
# Background
# -Tat tivi
# Tat tivi
# Tat tivi
# --Doremon
# Doremon
# Doremon
# Doremon
# -Tat tivi
# Tat tivi
# Tat tivi
# Background
# Background
# Background
# -Khoa cong
# Khoa cong
# Khoa cong
# --Khoa cong
# Khoa cong
# Khoa cong
# Khoa cong
# Background
# Background
# Background
# Background
# Background
# Tat tivi
# --Background
# -Doremon
# Tat tivi
# Background
# Bat tivi
# Background
# Background
# -Background
# -Background
# Background
# -Background
# Bat tivi
# Background
# -Doremon
# Doremon
# Doremon
# Khoa cong
# -Khoa cong
# Mo cong
# --Background
# -Bat dieu hoa
# -Khoa cong
# -Bat dieu hoa
# ----Bat tivi
# Tat tivi
# ---Background
# Doremon
# --Khoa cong
# Khoa cong
# Background
# --Background
# Background
# Background
# Background
# -Background
# Background
# -Tat tivi
# --Background
# Background
# --Background
# Background
# -Bat dieu hoa
# Bat dieu hoa
# -Background
# Background
# -Bat tivi
# Bat tivi
# --Background
# Background
# -Background
# -Doremon
# Doremon
# Doremon
# Doremon
# ---Background
# -Doremon
# Doremon
# Bat tivi
# Background
# --Bat quat
# Bat quat
# ----Bat quat
# Doremon
# Bat tivi
# ---Background
# -Mo cong
# Khoa cong
# ----Background
# Background
# -----Background
# Background
# Background
# Background
# Background
# Background
# Doremon
# --Background
# Background
# Background
# Background
# Background
# -Tat tivi
# Background
# --Background
# --Bat den
# -Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# ----Background
# Background
# Background
# Background
# Background
# Khoa cong
# Background
# Background
# Background
# Background
# Background
# Bat quat
# ---------Background
# -Khoa cong
# Background
# Background
# Background
# Background
# Background
# -Khoa cong
# Khoa cong
# Khoa cong
# Background
# Background
# Tat tivi
# Tat dieu hoa
# Tat dieu hoa
# Tat dieu hoa
# -Background
# Background
# Background
# Background
# Tat dieu hoa
# -Tat dieu hoa
# Doremon
# Background
# Background
# -Background
# ------Background
# Background
# Background
# Background
# ---Background
# -Tat tivi
# --Background
# Background
# Background
# Tat den
# Background
# -Tat tivi
# Background
# ---Background
# Background
# Background
# Background
# Background
# Background
# --Background
# Background
# --Bat tivi
# Bat tivi
# -------Background
# -Doremon
# Doremon
# Doremon
# -Khoa cong
# Khoa cong
# Khoa cong
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Tat dieu hoa
# Tat dieu hoa
# --Background
# Background
# Khoa cua
# Khoa cua
# Khoa cua
# Khoa cua
# Bat tivi
# Bat tivi
# --Mo cua
# Mo cua
# Mo cua
# Mo cua
# Background
# Background
# Background
# Background
# -Bat dieu hoa
# Doremon
# -Bat tivi
# Bat dieu hoa
# Khoa cua
# Khoa cong
# Khoa cong
# -Background
# Background
# Background
# Background
# Background
# Background
# Khoa cong
# Khoa cong
# Khoa cong
# -Background
# Background
# Background
# --Background
# -Bat tivi
# ----Mo cong
# Background
# Mo cong
# -Background
# Background
# Background
# Background
# Background
# -Bat tivi
# Bat tivi
# -Background
# Background
# Background
# Background
# Background
# Doremon
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# -Background
# Background
# -Background
# -----Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Tat den
# Background
# -Tat tivi
# Background
# Background
# Background
# -Background
# -Background
# Background
# --Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -------Background
# ----Bat dieu hoa
# -----Doremon
# Doremon
# --Background
# Khoa cong
# -Background
# Background
# --Tat dieu hoa
# Doremon
# Doremon
# --Background
# -Doremon
# Doremon
# -Background
# -Doremon
# -Doremon
# Doremon
# -Khoa cua
# -----Bat tivi
# Background
# Background
# Bat dieu hoa
# -Doremon
# -Doremon
# -----Background
# -Doremon
# Doremon
# Background
# Background
# -Background
# -Bat tivi
# --Doremon
# Tat tivi
# Tat tivi
# Tat tivi
# Doremon
# Bat tivi
# ---Background
# Background
# Background
# -------Background
# --Doremon
# Bat tivi
# Mo cua
# Background
# ----Background
# Bat tivi
# Bat tivi
# Bat tivi
# Bat tivi
# --Bat tivi
# -Khoa cua
# --Bat dieu hoa
# Doremon
# Doremon
# -Doremon
# -Doremon
# ---Doremon
# Doremon
# -Background
# --Bat tivi
# Bat tivi
# Bat dieu hoa
# Background
# Khoa cong
# Doremon
# Doremon
# Doremon
# Doremon
# -Bat tivi
# --Tat dieu hoa
# --Khoa cong
# --Doremon
# -Doremon
# Doremon
# -Doremon
# -Mo cong
# ---Mo cong
# -Background
# ----Doremon
# Doremon
# Background
# -Doremon
# -Bat tivi
# ------Doremon
# Doremon
# -Bat dieu hoa
# -Doremon
# Khoa cong
# -Background
# Background
# Background
# Background
# Background
# --Background
# -Background
# ---Doremon
# --Background
# ------Bat tivi
# Doremon
# Bat tivi
# -Background
# Background
# -Background
# Background
# --Background
# Background
# Background
# Background
# --Bat dieu hoa
# Bat dieu hoa
# Bat dieu hoa
# -Background
# Background
# Background
# Background
# ---Doremon
# -Doremon
# Background
# ---Doremon
# Doremon
# Doremon
# -Background
# Background
# Background
# -----Background
# Background
# ------Doremon
# --Doremon
# Doremon
# Doremon
# Background
# Background
# Doremon
# Khoa cong
# Khoa cong
# Khoa cong
# Bat tivi
# ---Bat den
# Bat tivi
# -Mo cong
# --Background
# ---Background
# Background
# --Background
# Bat dieu hoa
# Doremon
# Doremon
# Doremon
# -Background
# ----Background
# Background
# -Tat tivi
# Background
# ---Bat tivi
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# -Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Khoa cong
# -Background
# Background
# -Background
# Mo cong
# -Background
# Background
# -----Background
# Background
# Background
# Background
# -Background
# -Bat dieu hoa
# --Background
# Background
# Background
# Background
# -----Background
# -------Background
# -Background
# -----Background
# Background
# -Tat tivi
# Doremon
# --Mo cua
# Mo cua
# Mo cua
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# -Background
# -Tat den
# --Background
# -Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# Background
# Background
# --Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# Background
# --Bat dieu hoa
# ----Background
# Background
# Background
# Background
# Background
# Background
# ------Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Doremon
# --Doremon
# Background
# Background
# Background
# ----Background
# ---Doremon
# Background
# -Background
# Background
# Background
# Background
# --Background
# Background
# Background
# Background
# --Bat dieu hoa
# Doremon
# Doremon
# Background
# Doremon
# Background
# --Bat tivi
# Background
# -Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# Background
# --Khoa cua
# Bat tivi
# Background
# Background
# --Bat tivi
# ---Background
# -Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Doremon
# -Doremon
# Doremon
# Background
# Background
# --Bat tivi
# ---Background
# Bat tivi
# ---Doremon
# --Khoa cong
# --Doremon
# Background
# -Background
# Background
# -Background
# Background
# Background
# Background
# --Background
# Bat dieu hoa
# -Background
# -Background
# ---Background
# -Background
# Background
# Background
# ---Background
# Background
# Doremon
# --Doremon
# Background
# Background
# ---Bat dieu hoa
# ---Background
# Background
# Doremon
# Doremon
# -Doremon
# ----Bat dieu hoa
# -Background
# Background
# Background
# Background
# -Background
# --Bat den
# ----Background
# Background
# Background
# --Background
# ---Bat den
# Bat den
# Bat den
# -Background
# Background
# --Doremon
# Doremon
# Doremon
# Doremon
# Doremon
# -----Tat den
# Tat den
# ----Bat tivi
# Background
# Background
# --Bat dieu hoa
# Bat dieu hoa
# Doremon
# -Background
# Background
# Background
# Background
# --Doremon
# Doremon
# Doremon
# Doremon
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# Background
# -Bat dieu hoa
# ----Background
# Bat dieu hoa
# Bat dieu hoa
# Doremon
# -----Tat tivi
# -Background
# Background
# Background
# ---Bat tivi
# Bat dieu hoa
# Bat dieu hoa
# Background
# ---Bat tivi
# -Background
# Background
# -Tat tivi
# Mo cua
# -Bat dieu hoa
# ---Doremon
# Background
# Mo cong
# Mo cua
# -Background
# Bat tivi
# Background
# Bat tivi
# Background
# Khoa cong
# -Mo cua
# Bat tivi
# -Background
# Dong cua
# Mo cua
# --Bat tivi
# Background
# -Background
# --Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Background
# --Tat dieu hoa
# Tat dieu hoa
# -Background
# ---Background
# -----Background
# Background
# Bat dieu hoa
# Khoa cong
# Background
# Khoa cong
# Background
# Background
# -Doremon
# --Mo cua
# -Mo cong
# ----Background
# ------Background
# Background
# Doremon
# -Bat tivi
# Bat tivi
# Doremon
# Tat tivi
# ---Background
# ---Background
# -Background
# ------Khoa cong
# ---Bat tivi
# -Bat dieu hoa
# Doremon
# --Doremon
# Background
# ---Background
# -Background
# -Background
# -Doremon
# Background
# ---Bat quat
# -Khoa cong
# Khoa cong
# Background
# Background
# Background
# Bat dieu hoa
# --Bat dieu hoa
# -Doremon
# --Background
# Background
# Background
# Background
# Background
# Background
# Background
# --Mo cua
# --Bat tivi
# Background
# Bat tivi
# Background
# ---Background
# ---Background
# -Background
# Background
# Background
# Background
# -Bat quat
# Bat quat
# Bat quat
# Background
# -Doremon
# Doremon
# ---Bat tivi
# Bat tivi
# Bat tivi
# Background
# -Tat tivi
# Tat tivi
# Background
# Tat tivi
# ---Doremon
# -Background
# -----------Background
# Background
# Background
# --Khoa cong
# Khoa cong
# Khoa cong
# --Dong cua
# -Background
# -Background
# Background
# Background
# ---Doremon
# Doremon
# Background
# Doremon
# -Mo cua
# Doremon
# Doremon
# --Khoa cua
# Khoa cua
# Doremon
# Mo cong
# --Doremon
# Doremon
# Doremon
# Doremon
# --Khoa cong
# Khoa cong
# -------Doremon
# --Background
# -Khoa cua
# Khoa cong
# Khoa cong
# Khoa cong
# Tat den
# -----Background
# --Bat tivi
# -Bat tivi
# Background
# Bat dieu hoa
# --Background
# Background
# Background
# Background
# Background
# -Background
# Background
# Background
# -Background
# Background
# Khoa cong
# Background
# Background
# Background
# Background
# Background
# Background
# Background
# -Doremon
# Doremon
# Doremon
# --Background
# Background
# -Background
# Background
# Background
# Background
# Bat tivi
# Background
# Background
# Khoa cong
# Tat tivi
# Background
# Tat tivi
# Background
# Background
# Background
# -Doremon
# Doremon
# Doremon
# --Background
# Background
# ---Khoa cua
# Background
# Background
# --Background
# Background
# --Bat tivi
# Bat tivi
# Bat tivi
# -Bat tivi
# Background
# Background
# ----Bat quat
# -Khoa cua
# ---Bat tivi
# Bat tivi
# -Background
# Bat dieu hoa
# Background
# Background
# -Bat den
# -Bat den
# ------Background
# Background
# Background
# -----Background
# Background
# Dong cua
# -Background
# Background
# Bat tivi
# --Bat tivi
# ----Bat dieu hoa
# -Background
# --Doremon
# Background
# Background
# Background
# Background
# --Background
# -Background
# --Doremon
# -Khoa cua
# --Bat tivi
# Bat tivi
# -Tat tivi
# -Bat tivi
# Background
# --Bat tivi
# -Doremon
# Background
# Background
# Background
# -Background
# Background
# Background
# Background
# ----Background
# Background
# ---Bat tivi
# --Bat dieu hoa
# Bat dieu hoa
# Background
# Background
# -Background
# Bat tivi
# -Bat dieu hoa
# -Bat dieu hoa
# Khoa cua
# ---Background
# Background
# Tat tivi
# Tat den
# Background
# Background
# -Background
# Background
# -Background
# Background
# Background
# Background
# Background
# Background
# -Doremon
# Doremon
# Doremon
# --Background
# Background
# Background
# Background
# Background
# -Background
# --Background
# Background
# -Bat dieu hoa
# -Tat tivi
# Bat dieu hoa
# Doremon
# -Bat tivi
# ---Doremon
# Bat tivi
# Bat tivi
# Background
# ----
